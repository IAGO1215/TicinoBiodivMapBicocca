# %%
import os
import pandas as pd
import geopandas as gpd

# %%
# Set some directories. Here we use absolute directories. 
cwd = 'c:\\Users\\m1865\\Desktop\\Ticino'
cwd_Field = cwd + '\\FieldData\\ShapefileCorretti'
cwd_Agg = cwd + '\\FieldData\\ShapefileAggiunto'

# %%
gdf_Field = gpd.read_file(cwd_Field + '\\confini_foreste_corretti.shp')
gdf_Agg = gpd.read_file(cwd_Agg + '\\ticino_classification.shp')

# %%
gdf_Field.head()
# Out:
#    FID                                           geometry
# 0    0  POLYGON ((504873.482 5000610.888, 504808.988 5...
# 1    1  POLYGON ((504989.028 5000858.123, 505021.279 5...
# 2    2  POLYGON ((506827.044 5001023.389, 506896.914 5...
# 3    3  POLYGON ((507080.984 5001164.471, 507089.040 5...
# 4    4  POLYGON ((505300.743 5001126.854, 505335.674 5...

# %%
gdf_Agg.head()
# Out:
#    id                                           geometry
# 0   1  POLYGON ((470447.573 5066242.191, 471117.870 5...
# 1   2  POLYGON ((471877.758 5067247.400, 471685.552 5...
# 2   3  POLYGON ((473242.834 5065867.946, 472965.412 5...
# 3   4  POLYGON ((484814.271 5050487.661, 484998.392 5...
# 4   5  POLYGON ((473143.615 5056493.908, 473403.450 5...

# %%
gdf_Agg.rename(columns = {'id': 'FID'}, inplace = True)
gdf_Agg.head()
# Out:
#    FID                                           geometry
# 0    1  POLYGON ((470447.573 5066242.191, 471117.870 5...
# 1    2  POLYGON ((471877.758 5067247.400, 471685.552 5...
# 2    3  POLYGON ((473242.834 5065867.946, 472965.412 5...
# 3    4  POLYGON ((484814.271 5050487.661, 484998.392 5...
# 4    5  POLYGON ((473143.615 5056493.908, 473403.450 5...

# %%
gdf_Field.plot()
# Out:
# <Axes: >

# %%
gdf_Merge = pd.concat([gdf_Agg,gdf_Field])
gdf_Merge.head()
# Out:
#    FID                                           geometry
# 0    1  POLYGON ((470447.573 5066242.191, 471117.870 5...
# 1    2  POLYGON ((471877.758 5067247.400, 471685.552 5...
# 2    3  POLYGON ((473242.834 5065867.946, 472965.412 5...
# 3    4  POLYGON ((484814.271 5050487.661, 484998.392 5...
# 4    5  POLYGON ((473143.615 5056493.908, 473403.450 5...

# %%
gdf_Merge.plot()
# Out:
# <Axes: >

# %%
gdf_Merge.to_file(cwd + "\\FieldData\\ShapefileCorrettiAggiunto\\confini_foreste_estesi.shp")
