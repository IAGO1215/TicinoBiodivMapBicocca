# %%
import math
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Set some directories. Here we use absolute directories. 
cwd = 'c:\\Users\\m1865\\Desktop\\Ticino'
cwd_Field = cwd + '\\FieldData'
cwd_Field_Data2 = cwd_Field + '\\Field Dataset 2'
cwd_Result = cwd + '\\Results'

# %%
# Since our Excel file contains multiple sheets, we need to get the names of sheets firstly. 
xlsx = pd.ExcelFile(cwd_Field_Data2 + '\\Dati plot forestali Parco Ticino completo.xlsx')
xlsx.sheet_names
# Out:
# ['Querce caducifoglie',
#  'Acero-fra, Orno-ost',
#  'Castagneti',
#  'Pinete con lat',
#  'Lat alloctone',
#  'Lat meso con conifere',
#  'TEMPLATE']

# %%
# Combine! 
xlsx_field = pd.DataFrame()
for sheet in xlsx.sheet_names:
    if sheet != 'TEMPLATE':
        temp_df = pd.read_excel(cwd_Field_Data2 + '\\Dati plot forestali Parco Ticino completo.xlsx', sheet_name=sheet)
        xlsx_field = pd.concat([xlsx_field, temp_df], ignore_index=True)
xlsx_field
# Out:
#           Unnamed: 0 Unnamed: 1                          Unnamed: 2  \
# 0    Tipo forestale:        NaN  Querce caducifoglie (colore rosso)
# 1                NaN        NaN                                 NaN
# 2          ha factor  31.830989                                 NaN
# 3        Radius [m]          10                                 NaN
# 4                NaN        NaN                                 NaN
# ..               ...        ...                                 ...
# 972               40          9                                casa
# 973               40         10                                prse
# 974               40         11                                quro
# 975               40         12                                quro
# 976               40         13                                prse
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2          NaN        NaN        NaN
# 3          NaN        NaN        NaN
# 4          NaN        NaN        NaN
# ..         ...        ...        ...
# 972       25.5        NaN        NaN
# 973       10.5        NaN        NaN
# 974       41.5        NaN        NaN
# 975         48        NaN        NaN
# 976         13        NaN        NaN
#
# [977 rows x 6 columns]

# %%
# By observing our concatenated dataframe, we only need to keep the first 3 columns. 
# Drop those columns! 
xlsx_field = xlsx_field.drop(xlsx_field.iloc[:,np.r_[1,np.arange(3,6,1)]], axis = 1)
xlsx_field
# Out:
#           Unnamed: 0                          Unnamed: 2
# 0    Tipo forestale:  Querce caducifoglie (colore rosso)
# 1                NaN                                 NaN
# 2          ha factor                                 NaN
# 3        Radius [m]                                  NaN
# 4                NaN                                 NaN
# ..               ...                                 ...
# 972               40                                casa
# 973               40                                prse
# 974               40                                quro
# 975               40                                quro
# 976               40                                prse
#
# [977 rows x 2 columns]

# %%
# Now we need to drop the useless rows. If the first column of a row is not a numeric value, then it will be dropped. 
df_field = xlsx_field
for row in range(0,xlsx_field.shape[0]):
    # Get the index label of the current row! 
    temp_label = xlsx_field.iloc[row].name
    if str(xlsx_field.iloc[row,0]).isnumeric(): # Note: we have to convert the value to str first, otherwise we can't apply "isnumeric()" function. 
        continue
    else: 
        # Drop the row based on the label! 
        df_field = df_field.drop(index=temp_label, axis = 0)
# Reset index
df_field = df_field.reset_index(drop = True)
# Assign column names
df_field.columns = ["Plot Number", "Tree Species"]
# Finally we get our dataframe! 
df_field
# Out:
#     Plot Number Tree Species
# 0             1         quru
# 1             1         pisy
# 2             1         quru
# 3             1         quru
# 4             1         quru
# ..          ...          ...
# 834          40         casa
# 835          40         prse
# 836          40         quro
# 837          40         quro
# 838          40         prse
#
# [839 rows x 2 columns]

# %%
# Now we need to calculate the quantity of species in each plot! 
ds_count = df_field.groupby("Plot Number").count().iloc[:,0]
ds_count
# Out:
# Plot Number
# 1      9
# 2     27
# 3     27
# 4     36
# 5     18
# 6     23
# 7     16
# 8     16
# 9     24
# 10    20
# 11    17
# 12    35
# 13    22
# 14    10
# 15    30
# 16    28
# 17    17
# 18    19
# 19    29
# 20    20
# 21    19
# 22    15
# 23    19
# 24    14
# 25    23
# 26     8
# 27    26
# 28    24
# 29    14
# 30    15
# 31    10
# 32    50
# 33    30
# 34    27
# 35    14
# 36    23
# 37    12
# 38    21
# 39    19
# 40    13
# Name: Tree Species, dtype: int64

# %%
# Get the quantities of each species in each field plot! 
df_field_count = df_field.groupby(["Plot Number","Tree Species"], as_index = False).size()
df_field_count = df_field_count.rename(columns={'size': 'Species Count'})
df_field_count
# Out:
#      Plot Number Tree Species  Species Count
# 0              1         pisy              2
# 1              1         quru              7
# 2              2         pisy              1
# 3              2         prse             12
# 4              2         quro              5
# ..           ...          ...            ...
# 149           39         pisy              7
# 150           40         casa              2
# 151           40         pisy              2
# 152           40         prse              6
# 153           40         quro              3
#
# [154 rows x 3 columns]

# %%
# Add the total counts of all the species in each plot field into the dataframe! 
for row in range(0,df_field_count.shape[0]):
    df_field_count.loc[row,'Total Count'] = ds_count.loc[df_field_count.iloc[row]['Plot Number']]
df_field_count['Total Count'] = df_field_count['Total Count'].astype('int64')
df_field_count
# Out:
#      Plot Number Tree Species  Species Count  Total Count
# 0              1         pisy              2            9
# 1              1         quru              7            9
# 2              2         pisy              1           27
# 3              2         prse             12           27
# 4              2         quro              5           27
# ..           ...          ...            ...          ...
# 149           39         pisy              7           19
# 150           40         casa              2           13
# 151           40         pisy              2           13
# 152           40         prse              6           13
# 153           40         quro              3           13
#
# [154 rows x 4 columns]

# %%
df_field_shannon = df_field_count.copy()
df_field_shannon['pi'] = df_field_shannon['Species Count'] / df_field_shannon['Total Count']
df_field_shannon['-pilnpi'] = df_field_shannon['pi'] * np.log(df_field_shannon['pi']) * (-1)
df_field_shannon
# Out:
#      Plot Number Tree Species  Species Count  Total Count        pi   -pilnpi
# 0              1         pisy              2            9  0.222222  0.334239
# 1              1         quru              7            9  0.777778  0.195467
# 2              2         pisy              1           27  0.037037  0.122068
# 3              2         prse             12           27  0.444444  0.360413
# 4              2         quro              5           27  0.185185  0.312296
# ..           ...          ...            ...          ...       ...       ...
# 149           39         pisy              7           19  0.368421  0.367879
# 150           40         casa              2           13  0.153846  0.287970
# 151           40         pisy              2           13  0.153846  0.287970
# 152           40         prse              6           13  0.461538  0.356857
# 153           40         quro              3           13  0.230769  0.338385
#
# [154 rows x 6 columns]

# %%
df_field_shannon_final = df_field_shannon.groupby('Plot Number', as_index= False).sum().drop(columns=["Tree Species","Total Count","pi"])
df_field_shannon_final = df_field_shannon_final.rename(columns={"-pilnpi": "Shannon Index", "Species Count": "Total Count"})
df_field_shannon_final
# Out:
#     Plot Number  Total Count  Shannon Index
# 0             1            9       0.529706
# 1             2           27       1.277259
# 2             3           27       1.086655
# 3             4           36       1.334475
# 4             5           18       1.365077
# 5             6           23       1.187775
# 6             7           16       0.984087
# 7             8           16       1.263741
# 8             9           24       1.212466
# 9            10           20       0.790987
# 10           11           17       1.649989
# 11           12           35       1.144725
# 12           13           22       1.516522
# 13           14           10       1.313834
# 14           15           30       1.207741
# 15           16           28       1.251331
# 16           17           17       0.677909
# 17           18           19       1.164365
# 18           19           29       1.067472
# 19           20           20       0.394398
# 20           21           19       0.680629
# 21           22           15       0.803315
# 22           23           19       1.010210
# 23           24           14       1.400327
# 24           25           23       0.902183
# 25           26            8       0.974315
# 26           27           26       1.374115
# 27           28           24       1.339806
# 28           29           14       1.376055
# 29           30           15       1.235145
# 30           31           10       1.220607
# 31           32           50       0.742417
# 32           33           30       0.610864
# 33           34           27       1.124897
# 34           35           14       0.758937
# 35           36           23       0.691502
# 36           37           12       0.562335
# 37           38           21       0.846145
# 38           39           19       0.658110
# 39           40           13       1.271181

# %%
# Read another Excel file which contains all the geographical coordinates of the field plots! 
df_field_coord = pd.read_excel(cwd_Field_Data2 + "\\Dati coordinate plot forestali Parco Ticino.xlsx")
df_field_coord
# Out:
#     n° plot          Y         X
# 0         1  45.712265  8.757804
# 1         2  45.702801  8.750167
# 2         3  45.639628  8.666780
# 3         4  45.630213  8.667770
# 4         5  45.552661  8.703548
# 5         6  45.542031  8.705301
# 6         7  45.536410  8.704414
# 7         8  45.507882  8.706822
# 8         9  45.705440  8.675570
# 9        10  45.705992  8.660657
# 10       11  45.702652  8.740590
# 11       12  45.635437  8.692949
# 12       13  45.690295  8.655280
# 13       14  45.701860  8.676986
# 14       15  45.700178  8.735308
# 15       16  45.691169  8.691169
# 16       17  45.752679  8.622356
# 17       18  45.749294  8.658004
# 18       19  45.780050  8.659166
# 19       20  45.770427  8.667140
# 20       21  45.736700  8.693500
# 21       22  45.746195  8.651453
# 22       23  45.712181  8.674673
# 23       24  45.697661  8.693711
# 24       25  45.734065  8.681272
# 25       26  45.716861  8.750134
# 26       27  45.662977  8.678159
# 27       28  45.686945  8.747726
# 28       29  45.728045  8.678277
# 29       30  45.720438  8.717936
# 30       31  45.720792  8.754275
# 31       32  45.587609  8.736405
# 32       33  45.599377  8.737557
# 33       34  45.707818  8.677689
# 34       35  45.743313  8.627677
# 35       36  45.780064  8.668534
# 36       37  45.665895  8.682949
# 37       38  45.686724  8.756250
# 38       39  45.733749  8.696724
# 39       40  45.662013  8.737580

# %%
# Rename the columns !
df_field_coord.columns = ["Plot Number", "Latitude", "Longitude"]
df_field_coord
# Out:
#     Plot Number   Latitude  Longitude
# 0             1  45.712265   8.757804
# 1             2  45.702801   8.750167
# 2             3  45.639628   8.666780
# 3             4  45.630213   8.667770
# 4             5  45.552661   8.703548
# 5             6  45.542031   8.705301
# 6             7  45.536410   8.704414
# 7             8  45.507882   8.706822
# 8             9  45.705440   8.675570
# 9            10  45.705992   8.660657
# 10           11  45.702652   8.740590
# 11           12  45.635437   8.692949
# 12           13  45.690295   8.655280
# 13           14  45.701860   8.676986
# 14           15  45.700178   8.735308
# 15           16  45.691169   8.691169
# 16           17  45.752679   8.622356
# 17           18  45.749294   8.658004
# 18           19  45.780050   8.659166
# 19           20  45.770427   8.667140
# 20           21  45.736700   8.693500
# 21           22  45.746195   8.651453
# 22           23  45.712181   8.674673
# 23           24  45.697661   8.693711
# 24           25  45.734065   8.681272
# 25           26  45.716861   8.750134
# 26           27  45.662977   8.678159
# 27           28  45.686945   8.747726
# 28           29  45.728045   8.678277
# 29           30  45.720438   8.717936
# 30           31  45.720792   8.754275
# 31           32  45.587609   8.736405
# 32           33  45.599377   8.737557
# 33           34  45.707818   8.677689
# 34           35  45.743313   8.627677
# 35           36  45.780064   8.668534
# 36           37  45.665895   8.682949
# 37           38  45.686724   8.756250
# 38           39  45.733749   8.696724
# 39           40  45.662013   8.737580

# %%
# Merge! 
df_field_merged = pd.merge(df_field_shannon_final, df_field_coord, on = "Plot Number")
df_field_merged
# Out:
#     Plot Number  Total Count  Shannon Index   Latitude  Longitude
# 0             1            9       0.529706  45.712265   8.757804
# 1             2           27       1.277259  45.702801   8.750167
# 2             3           27       1.086655  45.639628   8.666780
# 3             4           36       1.334475  45.630213   8.667770
# 4             5           18       1.365077  45.552661   8.703548
# 5             6           23       1.187775  45.542031   8.705301
# 6             7           16       0.984087  45.536410   8.704414
# 7             8           16       1.263741  45.507882   8.706822
# 8             9           24       1.212466  45.705440   8.675570
# 9            10           20       0.790987  45.705992   8.660657
# 10           11           17       1.649989  45.702652   8.740590
# 11           12           35       1.144725  45.635437   8.692949
# 12           13           22       1.516522  45.690295   8.655280
# 13           14           10       1.313834  45.701860   8.676986
# 14           15           30       1.207741  45.700178   8.735308
# 15           16           28       1.251331  45.691169   8.691169
# 16           17           17       0.677909  45.752679   8.622356
# 17           18           19       1.164365  45.749294   8.658004
# 18           19           29       1.067472  45.780050   8.659166
# 19           20           20       0.394398  45.770427   8.667140
# 20           21           19       0.680629  45.736700   8.693500
# 21           22           15       0.803315  45.746195   8.651453
# 22           23           19       1.010210  45.712181   8.674673
# 23           24           14       1.400327  45.697661   8.693711
# 24           25           23       0.902183  45.734065   8.681272
# 25           26            8       0.974315  45.716861   8.750134
# 26           27           26       1.374115  45.662977   8.678159
# 27           28           24       1.339806  45.686945   8.747726
# 28           29           14       1.376055  45.728045   8.678277
# 29           30           15       1.235145  45.720438   8.717936
# 30           31           10       1.220607  45.720792   8.754275
# 31           32           50       0.742417  45.587609   8.736405
# 32           33           30       0.610864  45.599377   8.737557
# 33           34           27       1.124897  45.707818   8.677689
# 34           35           14       0.758937  45.743313   8.627677
# 35           36           23       0.691502  45.780064   8.668534
# 36           37           12       0.562335  45.665895   8.682949
# 37           38           21       0.846145  45.686724   8.756250
# 38           39           19       0.658110  45.733749   8.696724
# 39           40           13       1.271181  45.662013   8.737580

# %%
gdf_Shannon = gpd.GeoDataFrame(
    df_field_merged,
    geometry = gpd.points_from_xy(df_field_merged['Longitude'],df_field_merged['Latitude']),
    crs = 'EPSG:4326'
)
# Convert the crs from 4326 (WGS84) to 32632 (WGS84 UTM zone 32N)
gdf_Shannon = gdf_Shannon.to_crs(32632)
gdf_Shannon
# Out:
#     Plot Number  Total Count  Shannon Index   Latitude  Longitude  \
# 0             1            9       0.529706  45.712265   8.757804
# 1             2           27       1.277259  45.702801   8.750167
# 2             3           27       1.086655  45.639628   8.666780
# 3             4           36       1.334475  45.630213   8.667770
# 4             5           18       1.365077  45.552661   8.703548
# 5             6           23       1.187775  45.542031   8.705301
# 6             7           16       0.984087  45.536410   8.704414
# 7             8           16       1.263741  45.507882   8.706822
# 8             9           24       1.212466  45.705440   8.675570
# 9            10           20       0.790987  45.705992   8.660657
# 10           11           17       1.649989  45.702652   8.740590
# 11           12           35       1.144725  45.635437   8.692949
# 12           13           22       1.516522  45.690295   8.655280
# 13           14           10       1.313834  45.701860   8.676986
# 14           15           30       1.207741  45.700178   8.735308
# 15           16           28       1.251331  45.691169   8.691169
# 16           17           17       0.677909  45.752679   8.622356
# 17           18           19       1.164365  45.749294   8.658004
# 18           19           29       1.067472  45.780050   8.659166
# 19           20           20       0.394398  45.770427   8.667140
# 20           21           19       0.680629  45.736700   8.693500
# 21           22           15       0.803315  45.746195   8.651453
# 22           23           19       1.010210  45.712181   8.674673
# 23           24           14       1.400327  45.697661   8.693711
# 24           25           23       0.902183  45.734065   8.681272
# 25           26            8       0.974315  45.716861   8.750134
# 26           27           26       1.374115  45.662977   8.678159
# 27           28           24       1.339806  45.686945   8.747726
# 28           29           14       1.376055  45.728045   8.678277
# 29           30           15       1.235145  45.720438   8.717936
# 30           31           10       1.220607  45.720792   8.754275
# 31           32           50       0.742417  45.587609   8.736405
# 32           33           30       0.610864  45.599377   8.737557
# 33           34           27       1.124897  45.707818   8.677689
# 34           35           14       0.758937  45.743313   8.627677
# 35           36           23       0.691502  45.780064   8.668534
# 36           37           12       0.562335  45.665895   8.682949
# 37           38           21       0.846145  45.686724   8.756250
# 38           39           19       0.658110  45.733749   8.696724
# 39           40           13       1.271181  45.662013   8.737580
#
#                           geometry
# 0   POINT (481149.210 5062107.523)
# 1   POINT (480551.551 5061057.811)
# 2   POINT (474030.984 5054062.994)
# 3   POINT (474103.856 5053016.615)
# 4   POINT (476860.756 5044389.695)
# 5   POINT (476993.249 5043208.309)
# 6   POINT (476921.679 5042584.060)
# 7   POINT (477098.139 5039413.959)
# 8   POINT (474745.660 5061371.891)
# 9   POINT (473585.098 5061437.965)
# 10  POINT (479805.960 5061043.717)
# 11  POINT (476068.687 5053589.184)
# 12  POINT (473158.974 5059695.892)
# 13  POINT (474854.295 5060973.693)
# 14  POINT (479393.869 5060770.211)
# 15  POINT (475953.803 5059781.545)
# 16  POINT (470628.130 5066638.347)
# 17  POINT (473399.147 5066249.794)
# 18  POINT (473504.101 5069666.490)
# 19  POINT (474119.498 5068594.762)
# 20  POINT (476154.686 5064839.453)
# 21  POINT (472888.055 5065907.678)
# 22  POINT (474678.910 5062121.096)
# 23  POINT (476154.518 5060502.040)
# 24  POINT (475202.158 5064550.418)
# 25  POINT (480553.843 5062619.968)
# 26  POINT (474928.232 5056653.377)
# 27  POINT (480355.994 5059296.836)
# 28  POINT (474966.443 5063882.441)
# 29  POINT (478049.377 5063025.683)
# 30  POINT (480877.462 5063055.676)
# 31  POINT (479438.106 5048263.471)
# 32  POINT (479532.301 5049570.588)
# 33  POINT (474911.640 5061635.412)
# 34  POINT (471037.151 5065595.838)
# 35  POINT (474232.299 5069664.962)
# 36  POINT (475302.661 5056976.158)
# 37  POINT (481019.610 5059270.183)
# 38  POINT (476404.259 5064510.592)
# 39  POINT (479556.832 5056529.385)

# %%
gdf_Shannon_Buffer = gdf_Shannon.copy()
meter_Buffer = 10
gdf_Shannon_Buffer['geometry'] = gdf_Shannon_Buffer.geometry.buffer(meter_Buffer, cap_style = 3)

# %%
n_Plot = 3
xmin = gdf_Shannon_Buffer.bounds.iloc[n_Plot,0]
ymin = gdf_Shannon_Buffer.bounds.iloc[n_Plot,1]
xmax = gdf_Shannon_Buffer.bounds.iloc[n_Plot,2]
ymax = gdf_Shannon_Buffer.bounds.iloc[n_Plot,3]

# %%
from osgeo import gdal
import rasterio as rio
from rasterio.plot import show
res_Raster_Shannon = 5
temp = rio.open(cwd_Result + "\\" + "2022 06Cropped" + "\\SPCA\\Alpha\\Shannon_" + str(res_Raster_Shannon))
fig, ax = plt.subplots(1, figsize = (12, 12))
image_hidden = ax.imshow(temp.read()[0], 
                        cmap='turbo')
gdf_Shannon_Buffer.boundary.plot(ax = ax, color='black')
show(temp, ax = ax, cmap = 'turbo')
fig.suptitle("Shannon Index")
fig.colorbar(image_hidden, ax=ax, fraction=0.046, pad=0.04)
fig.tight_layout()
ax.set_xlim(474500, 475200)
ax.set_ylim(5061000, 5062000)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio\\_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:221, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: c:/Users/m1865/Desktop/Ticino/Results/2022 06Cropped/SPCA/Alpha/Shannon_5: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# c:\Users\m1865\Desktop\Ticino\Python\6-FieldData2 Shannon.ipynb Cell 18 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> from rasterio.plot import show
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> res_Raster_Shannon = 5
# ----> <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> temp = rio.open(cwd_Result + "\\" + "2022 06Cropped" + "\\SPCA\\Alpha\\Shannon_" + str(res_Raster_Shannon))
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a> fig, ax = plt.subplots(1, figsize = (12, 12))
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X23sZmlsZQ%3D%3D?line=6'>7</a> image_hidden = ax.imshow(temp.read()[0],
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X23sZmlsZQ%3D%3D?line=7'>8</a>                         cmap='turbo')
#
# File c:\ProgramData\Anaconda3\envs\Ticino\lib\site-packages\rasterio\env.py:451, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     448     session = DummySession()
#     450 with env_ctor(session=session):
# --> 451     return f(*args, **kwds)
#
# File c:\ProgramData\Anaconda3\envs\Ticino\lib\site-packages\rasterio\__init__.py:304, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     301 path = _parse_path(raw_dataset_path)
#     303 if mode == "r":
# --> 304     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     305 elif mode == "r+":
#     306     dataset = get_writer_for_path(path, driver=driver)(
#     307         path, mode, driver=driver, sharing=sharing, **kwargs
#     308     )
#
# File rasterio\\_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: c:/Users/m1865/Desktop/Ticino/Results/2022 06Cropped/SPCA/Alpha/Shannon_5: No such file or directory

# %%
from osgeo import gdal
import rasterio as rio
from rasterio.plot import show
res_Raster_Shannon = 5
temp = rio.open(cwd_Result + "\\" + "2022 06Cropped" + "\\SPCA\\Alpha\\Shannon_" + str(res_Raster_Shannon))
fig, ax = plt.subplots(1, figsize = (12, 12))
image_hidden = ax.imshow(temp.read()[0], 
                        cmap='turbo')
gdf_Shannon_Buffer.boundary.plot(ax = ax, color='black')
show(temp, ax = ax, cmap = 'turbo')
fig.suptitle("Shannon Index")
fig.colorbar(image_hidden, ax=ax, fraction=0.046, pad=0.04)
fig.tight_layout()
ax.set_xlim(xmin - 2*(xmax - xmin), xmin + 2*(xmax-xmin))
ax.set_ylim(ymin - 2*(ymax - ymin), ymin + 2*(ymax-ymin))
# plt.xticks(np.arange(xmin - 2*(xmax - xmin) - 6 - 20, xmin + 2*(xmax-xmin) - 6 - 20, 100))
# plt.yticks(np.arange(ymin - 2*(ymax - ymin) - 4 + 10, ymin + 2*(ymax-ymin) - 4, 100))
plt.grid()

# %%
# Read the Shannon index in our raster! 
raster_Shannon = temp.read(1)
# Get the bounds of our raster! 
raster_xmin = temp.bounds[0]
raster_ymin = temp.bounds[1]

# %%
# Now we need to check for each field plot polygon that how many "raster grids" each field plot overlaps. 
res_Satellite = 10
res_Pixel = res_Satellite * res_Raster_Shannon
list_RasterShannon = []
for n in range(0,gdf_Shannon_Buffer.shape[0]): 
    print("This is the number " + str(n) + " plot!")
    xmin = gdf_Shannon_Buffer.bounds.iloc[n,0]
    ymin = gdf_Shannon_Buffer.bounds.iloc[n,1]
    xmax = gdf_Shannon_Buffer.bounds.iloc[n,2]
    ymax = gdf_Shannon_Buffer.bounds.iloc[n,3]
    # Get the x value in the raster
    left_x = math.floor(xmax/res_Pixel)*res_Pixel + 10 if xmax > (math.floor(xmax/res_Pixel)*res_Pixel + 10) else math.floor(xmax/res_Pixel)*res_Pixel - 40
    # Get the y value in the raster
    top_y = math.floor(ymax/res_Pixel)*res_Pixel + 20 if ymax > (math.floor(ymax/res_Pixel)*res_Pixel + 20) else math.floor(ymax/res_Pixel)*res_Pixel - 30
    # Check how many pixels the field plot overlaps
    if xmin < left_x and ymin < top_y:
        print("This field plot overlaps 4 raster pixels!")
        # print("The bottomleft raster pixel topleft coordinate is (" + str(left_x - res_Pixel) + "," + str(top_y) + ")")
        # print("The topleft raster pixel topleft coordinate is (" + str(left_x - res_Pixel) + "," + str(top_y + res_Pixel) + ")")
        # print("The bottomright raster pixel topleft coordinate is (" + str(left_x) + "," + str(top_y) + ")")
        # print("The topright raster pixel topleft coordinate is (" + str(left_x) + "," + str(top_y + res_Pixel) + ")")
        row1, col1 = temp.index(left_x - res_Pixel, top_y)
        row2, col2 = temp.index(left_x - res_Pixel, top_y + res_Pixel)
        row3, col3 = temp.index(left_x, top_y)
        row4, col4 = temp.index(left_x, top_y + res_Pixel)
        temp_Shannon_BLeft = raster_Shannon[row1,col1]
        temp_Shannon_TLeft = raster_Shannon[row2,col2]
        temp_Shannon_BRight = raster_Shannon[row3,col3]
        temp_Shannon_TRight = raster_Shannon[row4,col4]
        print("The bottomleft raster Shannon index is equal to " + str(temp_Shannon_BLeft))
        print("The topleft raster Shannon index is equal to " + str(temp_Shannon_TLeft))
        print("The bottomright raster Shannon index is equal to " + str(temp_Shannon_BRight))
        print("The topright raster Shannon index is equal to " + str(temp_Shannon_TRight))
        temp_Shannon_BLeft_weight = (left_x - xmin) * (top_y - ymin) / (meter_Buffer * 2) ** 2
        temp_Shannon_TLeft_weight = (left_x - xmin) * (ymax - top_y) / (meter_Buffer * 2) ** 2
        temp_Shannon_BRight_weight = (xmax - left_x) * (top_y - ymin) / (meter_Buffer * 2) ** 2
        temp_Shannon_TRight_weight = (xmax - left_x) * (ymax - top_y) / (meter_Buffer * 2) ** 2
        temp_Shannon_Final = temp_Shannon_BLeft * temp_Shannon_BLeft_weight + temp_Shannon_TLeft * temp_Shannon_TLeft_weight + temp_Shannon_BRight * temp_Shannon_BRight_weight + temp_Shannon_TRight * temp_Shannon_TRight_weight
        list_RasterShannon.append(temp_Shannon_Final)

    elif xmin < left_x and not (ymin < top_y):
        # print("This field plot overlaps 2 horizontal raster pixels!")
        # print("The left raster pixel topleft coordinate is (" + str(left_x - res_Pixel) + "," + str(top_y + res_Pixel) + ")")
        # print("The right raster pixel topleft coordinate is (" + str(left_x) + "," + str(top_y + res_Pixel) + ")")
        row1, col1 = temp.index(left_x - res_Pixel, top_y + res_Pixel)
        row2, col2 = temp.index(left_x, top_y + res_Pixel)
        temp_Shannon_Left = raster_Shannon[row1,col1]
        temp_Shannon_Right = raster_Shannon[row2,col2]
        # print("The left raster pixel index is (" + str(row1) + "," + str(col1) + ") and right is (" + str(row2) + "," + str(col2) + ")")
        print("The left raster Shannon index is equal to " + str(temp_Shannon_Left))
        print("The right raster Shannon index is equal to " + str(temp_Shannon_Right))
        temp_Shannon_Left_weight = (left_x - xmin) / (meter_Buffer * 2)
        temp_Shannon_Right_weight = (xmax - left_x) / (meter_Buffer * 2)
        temp_Shannon_Final = temp_Shannon_Left * temp_Shannon_Left_weight + temp_Shannon_Right * temp_Shannon_Right_weight
        list_RasterShannon.append(temp_Shannon_Final)
    elif not (xmin < left_x) and ymin < top_y:
        print("This field plot overlaps 2 vertical raster pixels!")
        # print("The bottom raster pixel topleft coordinate is (" + str(left_x) + "," + str(top_y) + ")")
        # print("The top raster pixel topleft coordinate is (" + str(left_x) + "," + str(top_y + res_Pixel) + ")")
        row1, col1 = temp.index(left_x, top_y)
        row2, col2 = temp.index(left_x, top_y + res_Pixel)
        temp_Shannon_Bottom = raster_Shannon[row1,col1]
        temp_Shannon_Top = raster_Shannon[row2,col2]
        # print("The bottom raster pixel index is (" + str(row1) + "," + str(col1) + ") and top is (" + str(row2) + "," + str(col2) + ")")
        print("The bottom raster Shannon index is equal to " + str(temp_Shannon_Bottom))
        print("The top raster Shannon index is equal to " + str(temp_Shannon_Top))
        temp_Shannon_Bottom_weight = (top_y - ymin) / (meter_Buffer * 2)
        temp_Shannon_Top_weight = (ymax - top_y) / (meter_Buffer * 2)
        temp_Shannon_Final = temp_Shannon_Bottom * temp_Shannon_Bottom_weight + temp_Shannon_Top * temp_Shannon_Top_weight
        list_RasterShannon.append(temp_Shannon_Final)
    elif not (xmin < left_x) and not (ymin < top_y):
        print("This field plot only overlaps 1 raster pixel!")
        # print("The raster pixel topleft coordinate is (" + str(left_x) + "," + str(top_y + res_Pixel) + ")")
        row, col = temp.index(left_x, top_y + res_Pixel)
        # print("The raster pixel index is (" + str(row) + "," + str(col) + ")")
        print("The raster Shannon index is equal to " + str(raster_Shannon[row,col]))
        list_RasterShannon.append(raster_Shannon[row,col])
    print("--------")
# Out:
# This is the number 0 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to 0.80503356
# --------
# This is the number 1 plot!
# The left raster Shannon index is equal to 2.044264
# The right raster Shannon index is equal to 2.3257103
# --------
# This is the number 2 plot!
# This field plot overlaps 2 vertical raster pixels!
# The bottom raster Shannon index is equal to 1.7718072
# The top raster Shannon index is equal to 1.7230346
# --------
# This is the number 3 plot!
# This field plot overlaps 4 raster pixels!
# The bottomleft raster Shannon index is equal to 1.366474
# The topleft raster Shannon index is equal to 1.5804586
# The bottomright raster Shannon index is equal to 1.6455587
# The topright raster Shannon index is equal to 1.450127
# --------
# This is the number 4 plot!
# The left raster Shannon index is equal to 2.2886133
# The right raster Shannon index is equal to 1.820296
# --------
# This is the number 5 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to 1.6687948
# --------
# This is the number 6 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to 1.5682356
# --------
# This is the number 7 plot!
# This field plot overlaps 2 vertical raster pixels!
# The bottom raster Shannon index is equal to 2.0948186
# The top raster Shannon index is equal to 2.1572573
# --------
# This is the number 8 plot!
# This field plot overlaps 2 vertical raster pixels!
# The bottom raster Shannon index is equal to 2.4184554
# The top raster Shannon index is equal to 2.11355
# --------
# This is the number 9 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to 2.1223376
# --------
# This is the number 10 plot!
# The left raster Shannon index is equal to 1.8234434
# The right raster Shannon index is equal to 2.2378006
# --------
# This is the number 11 plot!
# The left raster Shannon index is equal to 2.3162792
# The right raster Shannon index is equal to 2.3209705
# --------
# This is the number 12 plot!
# The left raster Shannon index is equal to 1.856561
# The right raster Shannon index is equal to 1.8764318
# --------
# This is the number 13 plot!
# This field plot overlaps 4 raster pixels!
# The bottomleft raster Shannon index is equal to 1.6818192
# The topleft raster Shannon index is equal to 1.7651101
# The bottomright raster Shannon index is equal to 2.102276
# The topright raster Shannon index is equal to 1.9419327
# --------
# This is the number 14 plot!
# This field plot overlaps 2 vertical raster pixels!
# The bottom raster Shannon index is equal to 1.5754217
# The top raster Shannon index is equal to 1.4778076
# --------
# This is the number 15 plot!
# The left raster Shannon index is equal to 2.6190913
# The right raster Shannon index is equal to 2.4504282
# --------
# This is the number 16 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to nan
# --------
# This is the number 17 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to nan
# --------
# This is the number 18 plot!
# This field plot overlaps 4 raster pixels!
# The bottomleft raster Shannon index is equal to nan
# The topleft raster Shannon index is equal to nan
# The bottomright raster Shannon index is equal to nan
# The topright raster Shannon index is equal to nan
# --------
# This is the number 19 plot!
# The left raster Shannon index is equal to nan
# The right raster Shannon index is equal to nan
# --------
# This is the number 20 plot!
# The left raster Shannon index is equal to 2.3995876
# The right raster Shannon index is equal to 1.6223389
# --------
# This is the number 21 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to 1.9910966
# --------
# This is the number 22 plot!
# This field plot overlaps 2 vertical raster pixels!
# The bottom raster Shannon index is equal to 2.4976466
# The top raster Shannon index is equal to 2.5416467
# --------
# This is the number 23 plot!
# The left raster Shannon index is equal to 2.0903938
# The right raster Shannon index is equal to 2.3668072
# --------
# This is the number 24 plot!
# The left raster Shannon index is equal to 2.21071
# The right raster Shannon index is equal to 2.2073116
# --------
# This is the number 25 plot!
# This field plot overlaps 4 raster pixels!
# The bottomleft raster Shannon index is equal to nan
# The topleft raster Shannon index is equal to nan
# The bottomright raster Shannon index is equal to nan
# The topright raster Shannon index is equal to nan
# --------
# This is the number 26 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to 1.692846
# --------
# This is the number 27 plot!
# The left raster Shannon index is equal to 1.6359315
# The right raster Shannon index is equal to 1.804135
# --------
# This is the number 28 plot!
# The left raster Shannon index is equal to 1.9423783
# The right raster Shannon index is equal to 1.8998678
# --------
# This is the number 29 plot!
# This field plot overlaps 2 vertical raster pixels!
# The bottom raster Shannon index is equal to 2.1886342
# The top raster Shannon index is equal to 2.1963205
# --------
# This is the number 30 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to nan
# --------
# This is the number 31 plot!
# This field plot overlaps 2 vertical raster pixels!
# The bottom raster Shannon index is equal to 1.347496
# The top raster Shannon index is equal to 1.8845556
# --------
# This is the number 32 plot!
# This field plot overlaps 2 vertical raster pixels!
# The bottom raster Shannon index is equal to 1.6223428
# The top raster Shannon index is equal to 1.8365043
# --------
# This is the number 33 plot!
# The left raster Shannon index is equal to 2.114109
# The right raster Shannon index is equal to 1.8238392
# --------
# This is the number 34 plot!
# This field plot only overlaps 1 raster pixel!
# The raster Shannon index is equal to 2.1832533
# --------
# This is the number 35 plot!
# This field plot overlaps 2 vertical raster pixels!
# The bottom raster Shannon index is equal to nan
# The top raster Shannon index is equal to nan
# --------
# This is the number 36 plot!
# This field plot overlaps 4 raster pixels!
# The bottomleft raster Shannon index is equal to 2.593142
# The topleft raster Shannon index is equal to 1.1652135
# The bottomright raster Shannon index is equal to 2.1421533
# The topright raster Shannon index is equal to 1.5601597
# --------
# This is the number 37 plot!
# This field plot overlaps 4 raster pixels!
# The bottomleft raster Shannon index is equal to 2.047313
# The topleft raster Shannon index is equal to 2.1993349
# The bottomright raster Shannon index is equal to 1.6851305
# The topright raster Shannon index is equal to 1.8209978
# --------
# This is the number 38 plot!
# This field plot overlaps 4 raster pixels!
# The bottomleft raster Shannon index is equal to 1.4863582
# The topleft raster Shannon index is equal to 1.5328546
# The bottomright raster Shannon index is equal to 0.8133484
# The topright raster Shannon index is equal to 1.4343352
# --------
# This is the number 39 plot!
# This field plot overlaps 4 raster pixels!
# The bottomleft raster Shannon index is equal to 1.9769682
# The topleft raster Shannon index is equal to 1.8179716
# The bottomright raster Shannon index is equal to 2.1508234
# The topright raster Shannon index is equal to 2.084966
# --------

# %%
# Now we get a list where the values of the Shannon index calculated from our raster file for each plot is saved! 
list_RasterShannon
# Out:
# [0.80503356,
#  2.066085752787549,
#  1.764504827759278,
#  1.464949715988695,
#  2.036755674170483,
#  1.6687948,
#  1.5682356,
#  2.1071779943956046,
#  2.2371703412112334,
#  2.1223376,
#  1.9469249147737757,
#  2.32066247307268,
#  1.8654770932089544,
#  1.7933105506077378,
#  1.525587239186382,
#  2.5870220096207923,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.2174608332705166,
#  1.9910966,
#  2.522058055653151,
#  2.152838489736608,
#  2.2103433189737975,
#  nan,
#  1.692846,
#  1.6863420355275958,
#  1.9074289965771385,
#  2.1946614191747518,
#  nan,
#  1.4407040171434244,
#  1.7357200059316287,
#  1.945176839148077,
#  2.1832533,
#  nan,
#  1.4704662625797729,
#  1.761529241205678,
#  1.3480405339825987,
#  1.9130910436809698]

# %%
# Convert out list to a dataframe! 
df_raster_Shannon = pd.DataFrame(
    data = {
        'Plot Number': df_field_shannon_final['Plot Number'],
        'Raster Shannon Index': list_RasterShannon
    }
)
df_raster_Shannon
# Out:
#     Plot Number  Raster Shannon Index
# 0             1              0.805034
# 1             2              2.066086
# 2             3              1.764505
# 3             4              1.464950
# 4             5              2.036756
# 5             6              1.668795
# 6             7              1.568236
# 7             8              2.107178
# 8             9              2.237170
# 9            10              2.122338
# 10           11              1.946925
# 11           12              2.320662
# 12           13              1.865477
# 13           14              1.793311
# 14           15              1.525587
# 15           16              2.587022
# 16           17                   NaN
# 17           18                   NaN
# 18           19                   NaN
# 19           20                   NaN
# 20           21              2.217461
# 21           22              1.991097
# 22           23              2.522058
# 23           24              2.152838
# 24           25              2.210343
# 25           26                   NaN
# 26           27              1.692846
# 27           28              1.686342
# 28           29              1.907429
# 29           30              2.194661
# 30           31                   NaN
# 31           32              1.440704
# 32           33              1.735720
# 33           34              1.945177
# 34           35              2.183253
# 35           36                   NaN
# 36           37              1.470466
# 37           38              1.761529
# 38           39              1.348041
# 39           40              1.913091

# %%
df_Comparison = pd.merge(df_field_shannon_final, df_raster_Shannon, on = 'Plot Number')
df_Comparison = df_Comparison.dropna().reset_index(drop = True).drop(columns=['Total Count']).rename(columns={"Shannon Index": "Field Shannon Index"})
df_Comparison
# Out:
#     Plot Number  Field Shannon Index  Raster Shannon Index
# 0             1             0.529706              0.805034
# 1             2             1.277259              2.066086
# 2             3             1.086655              1.764505
# 3             4             1.334475              1.464950
# 4             5             1.365077              2.036756
# 5             6             1.187775              1.668795
# 6             7             0.984087              1.568236
# 7             8             1.263741              2.107178
# 8             9             1.212466              2.237170
# 9            10             0.790987              2.122338
# 10           11             1.649989              1.946925
# 11           12             1.144725              2.320662
# 12           13             1.516522              1.865477
# 13           14             1.313834              1.793311
# 14           15             1.207741              1.525587
# 15           16             1.251331              2.587022
# 16           21             0.680629              2.217461
# 17           22             0.803315              1.991097
# 18           23             1.010210              2.522058
# 19           24             1.400327              2.152838
# 20           25             0.902183              2.210343
# 21           27             1.374115              1.692846
# 22           28             1.339806              1.686342
# 23           29             1.376055              1.907429
# 24           30             1.235145              2.194661
# 25           32             0.742417              1.440704
# 26           33             0.610864              1.735720
# 27           34             1.124897              1.945177
# 28           35             0.758937              2.183253
# 29           37             0.562335              1.470466
# 30           38             0.846145              1.761529
# 31           39             0.658110              1.348041
# 32           40             1.271181              1.913091

# %%
df_Comparison.plot(x = 'Plot Number', y = ['Field Shannon Index', 'Raster Shannon Index'], kind = 'bar')
plt.xticks(rotation = 45)
plt.grid()
plt.show()

# %%
# Calculate some statistics
raster_Mean = df_Comparison['Raster Shannon Index'].mean()
raster_Max = df_Comparison['Raster Shannon Index'].max()
raster_Min = df_Comparison['Raster Shannon Index'].min()
raster_Med = df_Comparison['Raster Shannon Index'].median()
raster_STD = df_Comparison['Raster Shannon Index'].std()
field_Mean = df_Comparison['Field Shannon Index'].mean()
field_Max = df_Comparison['Field Shannon Index'].max()
field_Min = df_Comparison['Field Shannon Index'].min()
field_Med = df_Comparison['Field Shannon Index'].median()
field_STD = df_Comparison['Field Shannon Index'].std()

# %%
df_Statistics = pd.DataFrame(
    data = {
        'Field Shannon Index': [field_Mean, field_Max, field_Min, field_Med, field_STD],
        'Raster Shannon Index': [raster_Mean, raster_Max, raster_Min, raster_Med, raster_STD]
    },
    index = ['Mean', 'Max', 'Min', 'Median', 'STD']
)
df_Statistics
# Out:
#         Field Shannon Index  Raster Shannon Index
# Mean               1.085244              1.886457
# Max                1.649989              2.587022
# Min                0.529706              0.805034
# Median             1.187775              1.913091
# STD                0.299987              0.365750

# %%
# Null hypothesis! 
from scipy.stats import ttest_ind
t_stat, pvalue = ttest_ind(df_Comparison['Field Shannon Index'], df_Comparison['Raster Shannon Index'])
print(t_stat)
print(pvalue)
if pvalue < 0.05:
    print("We reject NULL HYPOTHESIS! Therefore we can conclude that there is a definite relationship between Field Shannon Index and Raster Shannon Index!")
else: 
    print("We fail to reject NULL HYPOTHESIS!")
# Out:
# -9.72991383574782
# 3.067383840252761e-14
# We reject NULL HYPOTHESIS! Therefore we can conclude that there is a definite relationship between Field Shannon Index and Raster Shannon Index!

# %%
df_Comparison.plot(x = 'Field Shannon Index', y = 'Raster Shannon Index', style = 'o', legend = False)
# Out:
# <Axes: xlabel='Field Shannon Index'>

# %%
# Pearson correlation
from scipy import stats
res = stats.pearsonr(df_Comparison['Field Shannon Index'], df_Comparison['Raster Shannon Index'])
res
# Out:
# PearsonRResult(statistic=0.3045921687718156, pvalue=0.084797409087951)

# %% [markdown]
# # Export as shapefile!

# %%
df_Export = pd.merge(df_Comparison, df_field_coord, on = 'Plot Number').drop(columns=['Field Shannon Index', 'Raster Shannon Index'])
gdf_Export = gpd.GeoDataFrame(
    df_Export,
    geometry = gpd.points_from_xy(df_Export['Longitude'],df_Export['Latitude']),
    crs = 'EPSG:4326'
)
# Convert the crs from 4326 (WGS84) to 32632 (WGS84 UTM zone 32N)
gdf_Export = gdf_Export.to_crs(32632)
gdf_Export
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\m1865\Desktop\Ticino\Python\6-FieldData2 Shannon.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> df_Export = pd.merge(df_Comparison, df_field_coord, on = 'Plot Number').drop(columns=['Field Shannon Index', 'Raster Shannon Index'])
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> gdf_Export = gpd.GeoDataFrame(
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a>     df_Export,
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X43sZmlsZQ%3D%3D?line=3'>4</a>     geometry = gpd.points_from_xy(df_Export['Longitude'],df_Export['Latitude']),
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X43sZmlsZQ%3D%3D?line=4'>5</a>     crs = 'EPSG:4326'
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a> )
#       <a href='vscode-notebook-cell:/c%3A/Users/m1865/Desktop/Ticino/Python/6-FieldData2%20Shannon.ipynb#X43sZmlsZQ%3D%3D?line=6'>7</a> # Convert the crs from 4326 (WGS84) to 32632 (WGS84 UTM zone 32N)
#
# NameError: name 'df_Comparison' is not defined

# %%
gdf_Export.to_file(cwd_Field_Data2 + "\\Plot.shp")
gdf_Export_Buffer = gdf_Export.copy()
gdf_Export_Buffer['geometry'] = gdf_Export_Buffer.geometry.buffer(25, cap_style = 3)
gdf_Export_Buffer.to_file(cwd_Field_Data2 + "\\PlotBuffer.shp")
# Out:
# C:\Users\m1865\AppData\Local\Temp\ipykernel_2440\3476334987.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_Export.to_file(cwd_Field_Data2 + "\\Plot.shp")
# C:\Users\m1865\AppData\Local\Temp\ipykernel_2440\3476334987.py:4: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_Export_Buffer.to_file(cwd_Field_Data2 + "\\PlotBuffer.shp")
