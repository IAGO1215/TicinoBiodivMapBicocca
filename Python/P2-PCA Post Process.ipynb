# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as colors
# 16 Oct 2023: gdal must be imported first, and then rasterio can be imported
from osgeo import gdal
import rasterio as rio
from rasterio.plot import show

# %%
# Set some directories. Here we use absolute directories. 
cwd = 'c:\\Users\\m1865\\Desktop\\Ticino'
cwd_PRISMA = cwd + "\\PRISMA Raster Raw\\Merged"
cwd_PRISMA_PCA = cwd + "\\ResultsPRISMA"

# %%
# Get the name of all the rasters in our folder
raster_Names = []
for item in [name.split('.')[0] for name in os.listdir(cwd_PRISMA)]:
    if item not in raster_Names:
        raster_Names.append(item)
raster_Names
# Out:
# ['PRS_L2D_STD_20220611_20220710_NS_mosaic_crop_smooth_v2i',
#  'PRS_L2D_STD_20220906_20220911_NS_mosaic_crop_smooth_v2i']

# %%
# Get the paths of all the PCA results
path_PCA = []
for name in raster_Names:
    temp = cwd_PRISMA_PCA + "\\" + name + "\\SPCA\\PCA"
    path_PCA.append(temp)
path_PCA
# Out:
# ['c:\\Users\\m1865\\Desktop\\Ticino\\ResultsPRISMA\\PRS_L2D_STD_20220611_20220710_NS_mosaic_crop_smooth_v2i\\SPCA\\PCA',
#  'c:\\Users\\m1865\\Desktop\\Ticino\\ResultsPRISMA\\PRS_L2D_STD_20220906_20220911_NS_mosaic_crop_smooth_v2i\\SPCA\\PCA']

# %%
# Save the PCA results produced in R Studio to a list
list_PCA = []
for path in path_PCA:
    temp = rio.open(path + "\\OutputPCA_228_PCs")
    list_PCA.append(temp)
list_PCA
# Out:
# [<open DatasetReader name='c:/Users/m1865/Desktop/Ticino/ResultsPRISMA/PRS_L2D_STD_20220611_20220710_NS_mosaic_crop_smooth_v2i/SPCA/PCA/OutputPCA_228_PCs' mode='r'>,
#  <open DatasetReader name='c:/Users/m1865/Desktop/Ticino/ResultsPRISMA/PRS_L2D_STD_20220906_20220911_NS_mosaic_crop_smooth_v2i/SPCA/PCA/OutputPCA_228_PCs' mode='r'>]

# %%
# Save figures
count = 0
for PCA in list_PCA:
    for i in range(PCA.count):
        temp = PCA.read(i+1)
        fig = plt.figure(figsize = (10, 10))
        plt.title(raster_Names[count] + "  PC " + str(i+1))
        # show(temp, ax = ax, cmap = 'turbo')
        plt.imshow(temp, vmin = np.nanmin(temp),vmax = np.nanmax(temp), cmap = 'turbo')
        plt.colorbar()
        plt.savefig(path_PCA[count] + "\\Fig\\PC" + str(i+1) + ".png")
        # We need to close the plot otherwise the output cell will be overwhelmed with the plots
        if i != 0:
            plt.close()
    count = count + 1

# %%
# Trying normalized plots
count = 0
for PCA in list_PCA:
    for i in range(PCA.count):
        if i == 6: 
            temp = PCA.read(i+1)
            fig = plt.figure(figsize = (10, 10))
            plt.title(raster_Names[count] + "  PC " + str(i+1))
            # show(temp, ax = ax, cmap = 'turbo')
            temp_Img = plt.imshow(temp, norm = colors.LogNorm(), cmap = 'turbo')
            plt.colorbar(temp_Img)
            # plt.savefig(path_PCA[count] + "\\Fig\\PC" + str(i+1) + ".png")
            # We need to close the plot otherwise the output cell will be overwhelmed with the plots
            # if i != 0:
            #     plt.close()
    count = count + 1
